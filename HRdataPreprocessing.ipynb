# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
# %matplotlib inline

# %%
path = "/Users/shuyi/Documents/OMSCS/MachineLearning/HW1/HRData/"
train_data_file = "HR_comma_sep.csv"
# load the data from preprocessing and feature engineering
train_data = pd.read_csv(path + train_data_file)

# %%
train_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
# Check to see if there are any missing values in our data set
train_data.isnull().any()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# sales                    False
# salary                   False
# dtype: bool

# %%
train_data.columns
# Out:
# Index(['left', 'satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
# Move the reponse variable "turnover" to the front of the table
front = train_data['left']
train_data.drop(labels=['left'], axis=1,inplace = True)
train_data.insert(0, 'left', front)
train_data.head()
# Out:
#    left  satisfaction_level  last_evaluation  number_project  \
# 0     1                0.38             0.53               2
# 1     1                0.80             0.86               5
# 2     1                0.11             0.88               7
# 3     1                0.72             0.87               5
# 4     1                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years  sales  salary
# 0                      0  sales     low
# 1                      0  sales  medium
# 2                      0  sales  medium
# 3                      0  sales     low
# ...

# %%
train_data.shape
# Out:
# (14999, 10)

# %%
print('the turn over rate for this company is ' + str(sum(train_data['left'])/train_data.shape[0]))
# Out:
# the turn over rate for this company is 0.238082538836

# %% [markdown]
# NOTE: When performing cross validation, its important to maintain this turnover ratio

# %%
#Correlation Matrix
corr = train_data.corr()

sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

corr
# Out:
#                            left  satisfaction_level  last_evaluation  \
# left                   1.000000           -0.388375         0.006567
# satisfaction_level    -0.388375            1.000000         0.105021
# last_evaluation        0.006567            0.105021         1.000000
# number_project         0.023787           -0.142970         0.349333
# average_montly_hours   0.071287           -0.020048         0.339742
# time_spend_company     0.144822           -0.100866         0.131591
# Work_accident         -0.154622            0.058697        -0.007104
# promotion_last_5years -0.061788            0.025605        -0.008684
#
#                        number_project  average_montly_hours  \
# left                         0.023787              0.071287
# satisfaction_level          -0.142970             -0.020048
# last_evaluation              0.349333              0.339742
# number_project               1.000000              0.417211
# ...

# %%
# save the data for the next step
train_data.to_csv(path + "step1.csv")
